# %%
import os
import pandas as pd
import re

print("Current working directory:")
print(os.getcwd())

DATA_DIR = "../data"

print("\nFiles in data folder:")
print(os.listdir(DATA_DIR))
# Out:
# Current working directory:
# C:\Users\sherl\review_trend_agent\notebooks
#
# Files in data folder:
# ['.ipynb_checkpoints', 'all_reviews.csv', 'daily_topics_extracted.csv']

# %%
csv_path = os.path.join(DATA_DIR, "all_reviews.csv")
df = pd.read_csv(csv_path)

print("Data loaded successfully")
print("Shape:", df.shape)

df.head()
# Out:
# Data loaded successfully
# Shape: (200, 12)
#                                reviewId            userName  \
# 0  7cf3ecd1-6712-40db-a0c1-5fb71f8fae58          Festr Rest
# 1  34452425-f95d-4c80-b9f4-0b207345c82b        Rupali Salvi
# 2  502fb7b7-c2d4-4c36-8e3a-69fc9afa67b0  Bhagya Doddagoudar
# 3  b976f6d9-9569-471b-a9e5-b9eb73d60e54       Naiki Hembram
# 4  f9fdc332-de3c-47a0-8c73-963d24502ec4          Sabir Alam
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  sometimes I didn't get my order but after 2 or...      4              0
# 1                                       best service      5              0
# 2                                               good      5              0
# 3                                      so lovely app      3              0
# 4  Neither the goods arrive quickly nor the calls...      1              1
#
#   reviewCreatedVersion                   at  \
# 0               4.99.0  2025-12-24 22:25:37
# 1               4.97.1  2025-12-24 22:25:33
# 2               4.99.0  2025-12-24 22:23:52
# 3               4.99.0  2025-12-24 22:21:51
# 4               4.99.0  2025-12-24 22:20:13
#
#                                         replyContent            repliedAt  \
# 0  Hey, thank you for your feedback. We request y...  2025-12-24 22:34:00
# 1  Hey there, thank you for the valuable feedback...  2025-12-24 22:33:56
# 2  Hey there, thank you for the valuable feedback...  2025-12-24 22:33:51
# 3  Hey there, thank you for the valuable feedback...  2025-12-24 22:22:34
# 4  Hi, we are sorry about this. Please help us wi...  2025-12-24 22:22:34
#
#   appVersion        date
# 0     4.99.0  2025-12-24
# 1     4.97.1  2025-12-24
# 2     4.99.0  2025-12-24
# 3     4.99.0  2025-12-24
# 4     4.99.0  2025-12-24

# %%
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"http\S+", "", text)     # remove URLs
    text = re.sub(r"[^a-z\s]", "", text)    # keep only letters
    text = re.sub(r"\s+", " ", text).strip()
    return text

df["clean_content"] = df["content"].apply(clean_text)

df[["content", "clean_content"]].head()
# Out:
#                                              content  \
# 0  sometimes I didn't get my order but after 2 or...
# 1                                       best service
# 2                                               good
# 3                                      so lovely app
# 4  Neither the goods arrive quickly nor the calls...
#
#                                        clean_content
# 0  sometimes i didnt get my order but after or ho...
# 1                                       best service
# 2                                               good
# 3                                      so lovely app
# 4  neither the goods arrive quickly nor the calls...

# %%
df["date"] = pd.to_datetime(df["date"])
print(df["date"].min(), "→", df["date"].max())
# Out:
# 2025-12-24 00:00:00 → 2025-12-24 00:00:00

# %%
df.columns
# Out:
# Index(['reviewId', 'userName', 'userImage', 'content', 'score',
#        'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent',
#        'repliedAt', 'appVersion', 'date', 'clean_content'],
#       dtype='object')

# %%
import pandas as pd
import os
import re

DATA_DIR = "../data"
csv_path = os.path.join(DATA_DIR, "all_reviews.csv")

df = pd.read_csv(csv_path)
print("CSV loaded:", df.shape)
df.head()
# Out:
# CSV loaded: (200, 12)
#                                reviewId            userName  \
# 0  7cf3ecd1-6712-40db-a0c1-5fb71f8fae58          Festr Rest
# 1  34452425-f95d-4c80-b9f4-0b207345c82b        Rupali Salvi
# 2  502fb7b7-c2d4-4c36-8e3a-69fc9afa67b0  Bhagya Doddagoudar
# 3  b976f6d9-9569-471b-a9e5-b9eb73d60e54       Naiki Hembram
# 4  f9fdc332-de3c-47a0-8c73-963d24502ec4          Sabir Alam
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                              content  score  thumbsUpCount  \
# 0  sometimes I didn't get my order but after 2 or...      4              0
# 1                                       best service      5              0
# 2                                               good      5              0
# 3                                      so lovely app      3              0
# 4  Neither the goods arrive quickly nor the calls...      1              1
#
#   reviewCreatedVersion                   at  \
# 0               4.99.0  2025-12-24 22:25:37
# 1               4.97.1  2025-12-24 22:25:33
# 2               4.99.0  2025-12-24 22:23:52
# 3               4.99.0  2025-12-24 22:21:51
# 4               4.99.0  2025-12-24 22:20:13
#
#                                         replyContent            repliedAt  \
# 0  Hey, thank you for your feedback. We request y...  2025-12-24 22:34:00
# 1  Hey there, thank you for the valuable feedback...  2025-12-24 22:33:56
# 2  Hey there, thank you for the valuable feedback...  2025-12-24 22:33:51
# 3  Hey there, thank you for the valuable feedback...  2025-12-24 22:22:34
# 4  Hi, we are sorry about this. Please help us wi...  2025-12-24 22:22:34
#
#   appVersion        date
# 0     4.99.0  2025-12-24
# 1     4.97.1  2025-12-24
# 2     4.99.0  2025-12-24
# 3     4.99.0  2025-12-24
# 4     4.99.0  2025-12-24

# %%
def clean_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()
    text = re.sub(r"[^a-z\s]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

# %%
df["clean_content"] = df["content"].apply(clean_text)
df["date"] = pd.to_datetime(df["date"])

df[["content", "clean_content", "date"]].head()
# Out:
#                                              content  \
# 0  sometimes I didn't get my order but after 2 or...
# 1                                       best service
# 2                                               good
# 3                                      so lovely app
# 4  Neither the goods arrive quickly nor the calls...
#
#                                        clean_content       date
# 0  sometimes i didn t get my order but after or h... 2025-12-24
# 1                                       best service 2025-12-24
# 2                                               good 2025-12-24
# 3                                      so lovely app 2025-12-24
# 4  neither the goods arrive quickly nor the calls... 2025-12-24

# %%
daily_groups = (
    df.groupby(df["date"].dt.date)
      .agg({
          "clean_content": list,
          "score": "mean",
          "content": "count"
      })
      .reset_index()
      .rename(columns={
          "date": "day",
          "content": "review_count",
          "score": "avg_rating"
      })
)

daily_groups
# Out:
#           day                                      clean_content  avg_rating  \
# 0  2025-12-24  [sometimes i didn t get my order but after or ...        3.79
#
#    review_count
# 0           200

# %%
daily_groups["combined_text"] = daily_groups["clean_content"].apply(
    lambda texts: " ".join(texts)
)

# %%
issue_keywords = {
    "delivery_delay": ["late", "delay", "delayed", "slow"],
    "missing_items": ["missing", "not received", "didnt get"],
    "refund_issues": ["refund", "money back"],
    "app_issues": ["crash", "bug", "error", "app not working"],
    "customer_support": ["support", "help", "customer care"]
}

# %%
def extract_topics(text):
    found = []
    text = text.lower()
    for topic, keywords in issue_keywords.items():
        if any(k in text for k in keywords):
            found.append(topic)
    return found

# %%
daily_groups["issues_detected"] = daily_groups["combined_text"].apply(extract_topics)

daily_groups[["day", "issues_detected"]]
# Out:
#           day                                    issues_detected
# 0  2025-12-24  [delivery_delay, missing_items, refund_issues,...

# %%
def sentiment_label(rating):
    if rating >= 4:
        return "positive"
    elif rating == 3:
        return "neutral"
    else:
        return "negative"

# %%
df["sentiment"] = df["score"].apply(sentiment_label)

df[["score", "sentiment"]].head()
# Out:
#    score sentiment
# 0      4  positive
# 1      5  positive
# 2      5  positive
# 3      3   neutral
# 4      1  negative

# %%
sentiment_daily = (
    df.groupby(df["date"].dt.date)
      .agg(
          avg_rating=("score", "mean"),
          review_count=("content", "count"),
          negative_pct=("sentiment", lambda x: (x == "negative").mean() * 100)
      )
      .reset_index()
      .rename(columns={"date": "day"})
)

sentiment_daily
# Out:
#           day  avg_rating  review_count  negative_pct
# 0  2025-12-24        3.79           200          26.5

# %%
def trend_label(row):
    if row["avg_rating"] >= 4 and row["negative_pct"] < 15:
        return "Healthy"
    elif row["avg_rating"] >= 3:
        return "Watch"
    else:
        return "Critical"

sentiment_daily["sentiment_status"] = sentiment_daily.apply(trend_label, axis=1)

sentiment_daily
# Out:
#           day  avg_rating  review_count  negative_pct sentiment_status
# 0  2025-12-24        3.79           200          26.5            Watch

# %%
negative_df = df[df["sentiment"] == "negative"].copy()

print("Negative reviews:", negative_df.shape[0])
negative_df[["content", "score"]].head()
# Out:
# Negative reviews: 53
#                                               content  score
# 4   Neither the goods arrive quickly nor the calls...      1
# 5                                              😍 fast      1
# 6   worst offers on this app , useless , just mark...      1
# 7                         tatttttttti aappppppppppppp      1
# 10  they do not deliver food, insted they make you...      1

# %%
ISSUE_KEYWORDS = {
    "delivery": ["late", "delay", "delayed", "slow", "waiting"],
    "refund": ["refund", "money", "returned", "return"],
    "support": ["support", "customer care", "executive", "help"],
    "order": ["cancel", "cancelled", "missing", "wrong order"],
    "payment": ["payment", "charged", "upi", "card"]
}

# %%
def extract_issues(text):
    text = text.lower()
    found = set()

    for issue, keywords in ISSUE_KEYWORDS.items():
        for word in keywords:
            if word in text:
                found.add(issue)

    return list(found)

# %%
negative_df["issues"] = negative_df["clean_content"].apply(extract_issues)

negative_df[["clean_content", "issues"]].head()
# Out:
#                                         clean_content issues
# 4   neither the goods arrive quickly nor the calls...     []
# 5                                                fast     []
# 6   worst offers on this app useless just marketin...     []
# 7                         tatttttttti aappppppppppppp     []
# 10  they do not deliver food insted they make you ...     []

# %%
issues_exploded = negative_df.explode("issues")

issues_exploded.head()
# Out:
#                                 reviewId         userName  \
# 4   f9fdc332-de3c-47a0-8c73-963d24502ec4       Sabir Alam
# 5   207dba44-aef0-433a-8152-0eee67638765  SUNNY CREATIONS
# 6   c94c5520-6c99-4f6f-a209-fa84abc7b3b0      Abhay Singh
# 7   e7048357-1d02-4378-88b2-256b0eccc65e      Aarav Singh
# 10  329f1425-c233-49f8-b3f6-9b4e0e448fde      VSHL Vishal
#
#                                             userImage  \
# 4   https://play-lh.googleusercontent.com/a/ACg8oc...
# 5   https://play-lh.googleusercontent.com/a-/ALV-U...
# 6   https://play-lh.googleusercontent.com/a-/ALV-U...
# 7   https://play-lh.googleusercontent.com/a-/ALV-U...
# 10  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                               content  score  thumbsUpCount  \
# 4   Neither the goods arrive quickly nor the calls...      1              1
# 5                                              😍 fast      1              0
# 6   worst offers on this app , useless , just mark...      1              0
# 7                         tatttttttti aappppppppppppp      1              0
# 10  they do not deliver food, insted they make you...      1              0
#
#    reviewCreatedVersion                   at  \
# 4                4.99.0  2025-12-24 22:20:13
# 5                   NaN  2025-12-24 22:17:24
# 6                4.99.0  2025-12-24 22:17:19
# 7                4.99.0  2025-12-24 22:16:47
# 10               4.99.0  2025-12-24 22:15:12
#
#                                          replyContent            repliedAt  \
# 4   Hi, we are sorry about this. Please help us wi...  2025-12-24 22:22:34
# 5   Hi, please write to us about your experience a...  2025-12-24 22:22:35
# 6   Hi there, we are sorry for any hassle you have...  2025-12-24 22:22:35
# 7   Hi, please write to us about your experience a...  2025-12-24 22:22:38
# 10  Hey there, we would like to get this checked t...  2025-12-24 22:22:39
#
#    appVersion       date                                      clean_content  \
# 4      4.99.0 2025-12-24  neither the goods arrive quickly nor the calls...
# 5         NaN 2025-12-24                                               fast
# 6      4.99.0 2025-12-24  worst offers on this app useless just marketin...
# 7      4.99.0 2025-12-24                        tatttttttti aappppppppppppp
# 10     4.99.0 2025-12-24  they do not deliver food insted they make you ...
#
#    sentiment issues
# 4   negative    NaN
# 5   negative    NaN
# 6   negative    NaN
# 7   negative    NaN
# 10  negative    NaN

# %%
root_causes = (
    issues_exploded["issues"]
    .value_counts()
    .reset_index()
    .rename(columns={"index": "issue", "issues": "count"})
)

root_causes
# Out:
#       count  count
# 0    refund      6
# 1  delivery      6
# 2     order      6
# 3   support      6
# 4   payment      1

# %%
import pandas as pd

df = pd.read_csv("../data/all_reviews.csv")
df["date"] = pd.to_datetime(df["date"])

df = df[["content", "date"]].dropna()
df.head()
# Out:
#                                              content       date
# 0  sometimes I didn't get my order but after 2 or... 2025-12-24
# 1                                       best service 2025-12-24
# 2                                               good 2025-12-24
# 3                                      so lovely app 2025-12-24
# 4  Neither the goods arrive quickly nor the calls... 2025-12-24

# %%
from sentence_transformers import SentenceTransformer
print("sentence-transformers loaded ✅")
# Out:
# sentence-transformers loaded ✅

# %%
import pandas as pd

df = pd.read_csv("../data/all_reviews.csv")
df["date"] = pd.to_datetime(df["date"])

df = df[["content", "date"]].dropna()
df.head()
# Out:
#                                              content       date
# 0  sometimes I didn't get my order but after 2 or... 2025-12-24
# 1                                       best service 2025-12-24
# 2                                               good 2025-12-24
# 3                                      so lovely app 2025-12-24
# 4  Neither the goods arrive quickly nor the calls... 2025-12-24

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("all-MiniLM-L6-v2")

embeddings = model.encode(
    df["content"].tolist(),
    show_progress_bar=True
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# C:\Users\sherl\review_agent_env\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\sherl\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
from sklearn.cluster import AgglomerativeClustering

clusterer = AgglomerativeClustering(
    n_clusters=None,
    distance_threshold=1.2
)

df["topic_cluster"] = clusterer.fit_predict(embeddings)

# %%
def name_topic(texts):
    return texts[0][:60] + "..."

topic_map = (
    df.groupby("topic_cluster")["content"]
      .apply(list)
      .apply(name_topic)
      .to_dict()
)

df["topic"] = df["topic_cluster"].map(topic_map)

df[["content", "topic"]].head()
# Out:
#                                              content  \
# 0  sometimes I didn't get my order but after 2 or...
# 1                                       best service
# 2                                               good
# 3                                      so lovely app
# 4  Neither the goods arrive quickly nor the calls...
#
#                                                topic
# 0  sometimes I didn't get my order but after 2 or...
# 1                                    best service...
# 2                                            good...
# 3                                   so lovely app...
# 4  Neither the goods arrive quickly nor the calls...

# %%
trend_table = (
    df.groupby(["topic", df["date"].dt.date])
      .size()
      .unstack(fill_value=0)
      .sort_index(axis=1)
)

trend_table.head()
# Out:
# date                                                2025-12-24
# topic
# 125 off but 80rs ka fried rice 350 ka padega pl...           2
# Exilent...                                                   3
# Good 👍...                                                   11
# I am already paying 1 rupees for 3 months deliv...           2
# I am book biryani rice is very worrest wast of ...           3

# %%
trend_table.to_csv("../output/topic_trend_report.csv")
print("✅ Trend report saved to /output/")
# Out:
# ✅ Trend report saved to /output/
